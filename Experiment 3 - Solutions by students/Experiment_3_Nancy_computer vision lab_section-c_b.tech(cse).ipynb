# %% [markdown]
# #Name-Nancy
# #Subject-Computer Vision Lab
# #CUID-CU240251005

# %% [markdown]
# #Experiment No. 3
# Experiment Name :-
# Implementation and Analysis of Spatial Filtering Techniques using Low-Pass and High-Pass
# Filters

# %% [markdown]
# 1. Import the required libraries and load a grayscale or color image for processing.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("/content/3d-cartoon-group.webp")

if img is None:
    print("Image not found")
else:
    print("Image loaded successfully")
# Out:
# Image loaded successfully

# %% [markdown]
# 2. Display the original image and analyze its visual characteristics.

# %%
# Convert BGR to RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display original image
plt.figure(figsize=(6, 5))
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")
plt.show()

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(6, 5))
plt.imshow(gray, cmap="gray")
plt.title("Grayscale Image")
plt.axis("off")
plt.show()

# %% [markdown]
# 3. Apply Gaussian Blur to reduce image noise while preserving important structures.

# %%
gaussian = cv2.GaussianBlur(gray, (3, 3), 0)
plt.figure(figsize=(6, 5))
plt.imshow(gaussian, cmap="gray")
plt.title("Gaussian Blur")
plt.axis("off")
plt.show()

# %% [markdown]
# 4. Apply Median Filtering to remove impulse (salt-and-pepper) noise from the image.

# %%
median = cv2.medianBlur(gray, 3)
plt.figure(figsize=(6, 5))
plt.imshow(median, cmap="gray")
plt.title("Median Filter")
plt.axis("off")
plt.show()

# %% [markdown]
# 5. Apply Average (Mean) Filtering and compare its smoothing performance with Gaussian
# filtering.

# %%
kernel = np.ones((3, 3), np.float32) / 9

average = cv2.filter2D(gray, -1, kernel)

plt.figure(figsize=(6, 5))
plt.imshow(average, cmap="gray")
plt.title("Average (Mean) Filter")
plt.axis("off")
plt.show()

# %% [markdown]
# 6. Implement Laplacian Filtering to enhance image edges and fine details.

# %%
laplacian = cv2.Laplacian(gray, cv2.CV_64F)

laplacian = cv2.convertScaleAbs(laplacian)

plt.figure(figsize=(6, 5))
plt.imshow(laplacian, cmap="gray")
plt.title("Laplacian Filter")
plt.axis("off")
plt.show()

# %% [markdown]
# 7. Apply Sobel Edge Detection in both horizontal and vertical directions to detect image
# gradients.

# %%
sobel_x = cv2.Sobel(
    gray,
    cv2.CV_64F,
    1,
    0,
    ksize=3
)

sobel_x = cv2.convertScaleAbs(sobel_x)

plt.figure(figsize=(6, 5))
plt.imshow(sobel_x, cmap="gray")
plt.title("Sobel X - Vertical Edges")
plt.axis("off")
plt.show()

# %% [markdown]
# 8. Compare the outputs of different low-pass and high-pass filters in terms of noise
# reduction, edge preservation, and computational performance.

# %%
sobel_y = cv2.Sobel(
    gray,
    cv2.CV_64F,
    0,
    1,
    ksize=3
)

sobel_y = cv2.convertScaleAbs(sobel_y)

plt.figure(figsize=(6, 5))
plt.imshow(sobel_y, cmap="gray")
plt.title("Sobel Y - Horizontal Edges")
plt.axis("off")
plt.show()

# %% [markdown]
# 9. Display the original and filtered images along with suitable observations highlighting
# the strengths and limitations of each filtering technique.

# %%
plt.figure(figsize=(14, 10))

plt.subplot(3, 3, 1)
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")

plt.subplot(3, 3, 2)
plt.imshow(gaussian, cmap="gray")
plt.title("Gaussian Blur")
plt.axis("off")

plt.subplot(3, 3, 3)
plt.imshow(median, cmap="gray")
plt.title("Median Filter")
plt.axis("off")

plt.subplot(3, 3, 4)
plt.imshow(average, cmap="gray")
plt.title("Average Filter")
plt.axis("off")

plt.subplot(3, 3, 5)
plt.imshow(laplacian, cmap="gray")
plt.title("Laplacian Filter")
plt.axis("off")

plt.subplot(3, 3, 6)
plt.imshow(sobel_x, cmap="gray")
plt.title("Sobel X")
plt.axis("off")

plt.subplot(3, 3, 7)
plt.imshow(sobel_y, cmap="gray")
plt.title("Sobel Y")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# 10. Interpret the results and discuss the applications of spatial filtering in real-world
# computer vision systems.

# %%
print("1. Gaussian Filter:")
print("   Smooths the image and reduces noise.")

print("\n2. Median Filter:")
print("   Removes salt-and-pepper noise and preserves edges.")

print("\n3. Average Filter:")
print("   Provides uniform smoothing but may blur edges.")

print("\n4. Laplacian Filter:")
print("   Enhances edges and fine details.")

print("\n5. Sobel X:")
print("   Detects vertical edges.")

print("\n6. Sobel Y:")
print("   Detects horizontal edges.")
# Out:
# 1. Gaussian Filter:
#    Smooths the image and reduces noise.
#
# 2. Median Filter:
#    Removes salt-and-pepper noise and preserves edges.
#
# 3. Average Filter:
#    Provides uniform smoothing but may blur edges.
#
# 4. Laplacian Filter:
#    Enhances edges and fine details.
#
# 5. Sobel X:
#    Detects vertical edges.
#
# 6. Sobel Y:
#    Detects horizontal edges.
